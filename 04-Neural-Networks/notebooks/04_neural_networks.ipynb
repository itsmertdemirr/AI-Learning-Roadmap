# %% [markdown]
# # Bölüm 04 — Sinir Ağları Derin İnceleme
#
# Bu notebook, bölümdeki temel kavramları etkileşimli olarak keşfetmenizi sağlar.
# Tam teori için [README.md](../README.md) dosyasına bakın.

# %% [markdown]
# ## 1. Tek Bir Nöronun Matematiği

# %%
import numpy as np

inputs = np.array([1.0, 0.5, -1.5])
weights = np.array([0.4, -0.6, 0.3])
bias = 0.1

z = np.dot(inputs, weights) + bias
a = 1 / (1 + np.exp(-z))  # sigmoid

print(f"z = {z:.4f}")
print(f"sigmoid(z) = {a:.4f}")

# %% [markdown]
# ## 2. Aktivasyon Fonksiyonlarını Görselleştirme

# %%
import matplotlib.pyplot as plt

x = np.linspace(-6, 6, 200)
sigmoid = 1 / (1 + np.exp(-x))
relu = np.maximum(0, x)
tanh = np.tanh(x)

plt.figure(figsize=(8, 5))
plt.plot(x, sigmoid, label="Sigmoid")
plt.plot(x, tanh, label="Tanh")
plt.plot(x, relu, label="ReLU")
plt.legend()
plt.grid(alpha=0.3)
plt.title("Aktivasyon Fonksiyonları Karşılaştırması")
plt.show()

# %% [markdown]
# ## 3. Deneyin!
#
# Ağırlıkları ve girdileri değiştirip farklı z ve aktivasyon değerleri elde edin. Ardından `examples/` klasöründeki 10 örneğin tamamını tek tek inceleyin.

# %%
# Kendi denemenizi buraya yazın
inputs = np.array([0.2, -0.8])
weights = np.array([1.0, 1.0])
bias = 0.0
z = np.dot(inputs, weights) + bias
print(f"z = {z}")

# %% [markdown]
# ## 4. Sıradaki Adımlar
#
# - `examples/` klasöründeki diğer 9 örneği inceleyin (ağırlık başlatma, dropout, batch norm, MLP sınıflandırıcı vb.)
# - `exercises/exercises.md` alıştırmalarını çözün
# - `quizzes/quiz.md` ile bilginizi test edin
# - `projects/hyperparameter_lab.md` kapsamlı projesini tamamlayın
# - Bölüm 5'e geçin: [Bilgisayarlı Görü](../../05-Computer-Vision/README.md)
